# %% [markdown]
# ># Exploratory Data Analysis for HR Employee Attrition

# %% [markdown]
# ![Employee_Attrition.webp](attachment:Employee_Attrition.webp)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Employee attrition, the phenomenon of employees leaving a company, is a significant concern for organizations. It impacts productivity, morale, and overall business performance.
#
# In the modern business landscape, retaining talented employees is paramount for sustained success. High attrition rates can disrupt workflow, increase recruitment costs, and lead to a loss of valuable institutional knowledge. Consequently, organizations strive to identify the underlying reasons for employee turnover and develop strategies to mitigate it.
#
# This project delves into the world of HR data analytics, where we explore a comprehensive dataset to uncover patterns, trends, and potential drivers of employee attrition. By analyzing variables such as age, gender, salary, and other relevant factors, we aim to provide actionable insights that can inform HR policies, improve employee retention, and ultimately contribute to the organization's long-term success.

# %% [markdown]
# ## Objectives

# %% [markdown]
# The primary objectives of this analysis are as follows:
#
# 1. Understand the factors contributing to employee attrition.
# 2. Identify patterns and trends related to attrition.
# 3. Develop actionable recommendations for reducing attrition.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# ## Importing the Dataset

# %%
df = pd.read_csv("HR-Employee-Attrition.csv")

# %% [markdown]
# ## Exploring the Dataset

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
# Checking for Null Values

df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Plotting a Correlation Map to check for Relationships

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(), annot = True, fmt = ".2f", linewidth = .5 , ax = ax)
plt.show()
# Out:
# C:\Users\ELITEBOOK\AppData\Local\Temp\ipykernel_12148\2132607650.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, fmt = ".2f", linewidth = .5 , ax = ax)

# %% [markdown]
# ## Attrition by Age Group

# %%
# segmenting the Age

bins = [0,26,42,58,80]
Labels = ["Gen Z","Millennials","Gen X","Baby Boomers"]
df["Age Group"] = pd.cut(df["Age"],bins=bins,labels=Labels)

# %%
# Employee Age Group distribution

df.groupby(["Age Group"]).size().reset_index(name="count").sort_values("count",ascending = False)
# Out:
#       Age Group  count
# 1   Millennials    929
# 2         Gen X    364
# 0         Gen Z    162
# 3  Baby Boomers     15

# %%
Attrition_AgeGroup = df.groupby(["Age Group", "Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_AgeGroup.plot(kind = "bar",figsize=(5,4))

# adding the title and labels

plt.title("Attrition by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.xticks(rotation=45)


# Adding the legend

plt.legend(title = "Attrition",loc = "upper right",fontsize = 6)

# adding the data labels

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")

# Show the plot

plt.show()

# %% [markdown]
# Millennials, representing the largest age group among employees with a total of 929 individuals, also recorded the highest number of attrition cases. Surprisingly, out of the 929 millennial employees, a total of 137 chose to leave the company during the specified period.

# %% [markdown]
# ## Attrition by Business Travels

# %%
# Employee Business Travel distribution

df.groupby(["BusinessTravel"]).size().reset_index(name = "count").sort_values("count",ascending = False)
# Out:
#       BusinessTravel  count
# 2      Travel_Rarely   1043
# 1  Travel_Frequently    277
# 0         Non-Travel    150

# %%
# Calculating the Attrition by Business Travel

Attrition_BusinessTravel = df.groupby(["BusinessTravel","Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_BusinessTravel.plot(kind = "bar",figsize=(6,4))

# adding the title and labels

plt.title("Attrition by Business Travel")
plt.xlabel("Business Travel")
plt.ylabel("count")
plt.xticks(rotation = 45)

# adding the legend

plt.legend(title = "Attrition", loc = "upper right", fontsize = 6)

# adding the data labels 

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")

# showing the chart

plt.show()

# %% [markdown]
# Surprisingly, employees who rarely travel have recorded the highest attrition within the company. This unexpected trend raises questions about the potential factors contributing to attrition among employees who do not frequently travel for work. Specifically, out of the 1043 employees who rarely travel, a total of 156 employees left the company.

# %% [markdown]
# ## Attrition by Department

# %%
# Employee distribution per department

df.groupby(["Department"]).size().reset_index(name="count").sort_values("count",ascending = False)
# Out:
#                Department  count
# 1  Research & Development    961
# 2                   Sales    446
# 0         Human Resources     63

# %%
# Calculating the attrition by department 

Attrition_department = df.groupby(["Department","Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_department.plot(kind = "bar",figsize = (5,4))

# adding the title and lables

plt.title("Attrition by Department")
plt.xlabel("Department")
plt.ylabel("count")
plt.xticks(rotation  = 45)

# adding the legend

plt.legend(title = "Attrition",loc = "upper right", fontsize = 6)

# adding the data labels

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")

# showing the chart

plt.show()

# %% [markdown]
# The data reveals that the Research and Development department had the highest attrition rate among employees. This finding underscores the importance of exploring the underlying factors contributing to attrition within this specific department which has the highest number of employees in the company. Specifically, out of the 961 employees in the Research and Development department, a total of 133 employees left.

# %% [markdown]
# ## Attrition by Education Level

# %%
# Employee distribution per Education level

df.groupby(["Education"]).size().reset_index(name="count").sort_values("count", ascending = False)
# Out:
#    Education  count
# 2          3    572
# 3          4    398
# 1          2    282
# 0          1    170
# 4          5     48

# %%
# calculating the attrition by Education level

Attrition_education = df.groupby(["Education","Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_education.plot(kind = "bar",figsize = (5,4))

# adding the title and labels

plt.title("Attrition by Education level")
plt.xlabel("Education level")
plt.ylabel("count")
plt.xticks(rotation = 360)

# adding the legend

plt.legend(title = "Attrition", loc = "upper right", fontsize = 6)


# adding the data labels

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")

# showing the chart

plt.show()

# %% [markdown]
# Remarkably, employees who completed only level 3 education experienced the highest attrition rate, with a total of 99 employees leaving the company. This finding underscores the significance of investigating the factors contributing to attrition among employees with this specific educational background.

# %% [markdown]
# ## Attrition by Education Field

# %%
# Employee distribution per Education Field

df.groupby(["EducationField"]).size().reset_index(name="count").sort_values("count", ascending = False)
# Out:
#      EducationField  count
# 1     Life Sciences    606
# 3           Medical    464
# 2         Marketing    159
# 5  Technical Degree    132
# 4             Other     82
# 0   Human Resources     27

# %%
# calculating the attrition by Education Field

Attrition_education_field = df.groupby(["EducationField","Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_education_field.plot(kind = "bar",figsize = (5,4))

# adding the title and labels

plt.title("Attrition by Education Field")
plt.xlabel("Education Field")
plt.ylabel("count")
plt.xticks(rotation = 45)

# adding the legend

plt.legend(title = "Attrition", loc = "upper right", fontsize = 6)


# adding the data labels

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")

# showing the chart

plt.show()

# %% [markdown]
# Notably, employees who studied in the field of Life Sciences exhibited the highest attrition rate, with a total of 89 individuals leaving the company. This observation prompts a closer examination of the factors contributing to attrition among employees with a background in Life Sciences.

# %% [markdown]
# ## Attrition by Marital Status

# %%
# Employee distribution by Marital Status

df.groupby(["MaritalStatus"]).size().reset_index(name = "count").sort_values("count",ascending = False)
# Out:
#   MaritalStatus  count
# 1       Married    673
# 2        Single    470
# 0      Divorced    327

# %%
# Calculating the Attrition by Marital Status

Attrition_marital_status = df.groupby(["MaritalStatus","Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax=Attrition_marital_status.plot(kind = "bar", figsize = (5,4))

# adding the title and labels

plt.title("Attrition by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("count")
plt.xticks(rotation = 45)

# adding the legend

plt.legend(title = "Attrition",loc = "upper right", fontsize = 6)

# adding the data labels

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")
    
# showing the chart

plt.show()

# %% [markdown]
# Employees who are single accounted for the highest attrition, with a total of 120 employees leaving the company. This observation suggests that marital status may play a role in attrition rates. Understanding the reasons behind this trend could help HR departments develop strategies to better retain single employees and improve overall employee satisfaction and retention.

# %% [markdown]
# ## Attrition by Job Role

# %%
# Employee distribution per job role

df.groupby(["JobRole"]).size().reset_index(name="count").sort_values("count",ascending= False)
# Out:
#                      JobRole  count
# 7            Sales Executive    326
# 6         Research Scientist    292
# 2      Laboratory Technician    259
# 4     Manufacturing Director    145
# 0  Healthcare Representative    131
# 3                    Manager    102
# 8       Sales Representative     83
# 5          Research Director     80
# 1            Human Resources     52

# %%
# calculating the attrition per job role

Attrition_jobrole = df.groupby(["JobRole", "Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_jobrole.plot(kind = "barh", figsize = (7,6))

# adding the title and labels

plt.title("Attrition by Job Role")
plt.xlabel("Job Role")
plt.ylabel("count")
plt.xticks(rotation = 45)

# adding the legend

plt.legend(title = "Attrition",loc = "upper right", fontsize = 6)

for p in ax.patches:
    ax.annotate("{:.0f}".format(p.get_width()), (p.get_width(), p.get_y() + p.get_height() / 2),
        ha="center", va="center", fontsize = 8,xytext=(10, 0), textcoords="offset points")
    
# showing the chart

plt.show()

# %% [markdown]
# The highest attrition was recorded among employees who work as Laboratory Technicians, with a total of 62 employees leaving the company. This finding highlights the need to investigate the specific factors contributing to attrition within this job role. Understanding these factors can help organizations develop targeted strategies to reduce attrition among Laboratory Technicians and improve overall employee retention.

# %% [markdown]
# ### Attrition by Gender

# %%
# Employee Gender distribution

df.groupby(["Gender"]).size().reset_index(name = "count")
# Out:
#    Gender  count
# 0  Female    588
# 1    Male    882

# %%
# Calculating the attrition by Gender

Attrition_Gender = df.groupby(["Gender","Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_Gender.plot(kind = "bar", figsize = (5,4))

# adding the title and labels

plt.title("Attrition by Gender")
plt.xlabel("Gender")
plt.ylabel("Attrition")
plt.xticks(rotation = 45)

# adding the legend

plt.legend (title = "Attrition", loc = "upper right", fontsize = 6)

# adding the data labels

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=8, color="black", xytext=(0, 5),
                textcoords="offset points")
    
# showing the chart

plt.show()

# %% [markdown]
# The highest attrition recorded was among male employees, with a total of 150 male employees leaving the company. Interestingly, male employees also represent the largest employee group, with a total of 882 employees. This finding suggests the need to investigate the specific factors contributing to attrition among male employees and to develop strategies to address this issue effectively.

# %% [markdown]
# ### Attrition by Total Working Years (Tenure)

# %%
# segmenting the total working days

bins = [-1,5,10,15,20,40]
Labels = ["Junior","Intermediate","Senior","Veteran","Long-Service"]
df["Tenure"] = pd.cut(df["YearsAtCompany"], bins = bins, labels = Labels)

# %%
# Employee distribution by Tenure

df.groupby(["Tenure"]).size().reset_index(name = "count").sort_values("count", ascending = False)
# Out:
#          Tenure  count
# 0        Junior    776
# 1  Intermediate    448
# 2        Senior    108
# 3       Veteran     72
# 4  Long-Service     66

# %%
# Calculating the atttrition by Tenure

Attrition_tenure = df.groupby(["Tenure","Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_tenure.plot(kind = "bar", figsize = (5,4))

# adding the title and labels

plt.title("Attrition by Total Working Years (Tenure)")
plt.xlabel("Tenure")
plt.ylabel("count")
plt.xticks(rotation = 45)

# adding the legend

plt.legend(title = "Attrition", loc = "upper right", fontsize = 6)

# adding the data labels 

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")

# showing the chart

plt.show()

# %% [markdown]
# Junior employees, those with 0 - 5 years of experience, are the most affected by attrition, with a total of 162 employees leaving the company. It's noteworthy that this group also represents the largest employee segment within the organization. This observation emphasizes the importance of addressing attrition concerns among junior employees to enhance employee retention and overall organizational stability.

# %% [markdown]
# ### Attrition by Number of Companies Worked

# %%
# Segmenting the Number of Companies Worked

bins = [-1,3,6,9]
labels = ["0 - 3","4 - 6", "7 - 9"]
df["PreviousEmployers"] = pd.cut(df["NumCompaniesWorked"], bins = bins,labels = labels)

# %%
# Employee distribution by Number of previous employers

df.groupby(["PreviousEmployers"]).size().reset_index(name = "count")
# Out:
#   PreviousEmployers  count
# 0             0 - 3   1023
# 1             4 - 6    272
# 2             7 - 9    175

# %%
# Calculating the attrition by Number of companies worked

Attrition_numofemployers = df.groupby(["PreviousEmployers", "Attrition"]).size().unstack().fillna(0)

ax = Attrition_numofemployers.plot(kind = "bar", figsize = (5,4))

# adding the title and labels

plt.title("Attrition by Number of Companies Worked")
plt.xlabel("Number of Companies Worked")
plt.ylabel("count")
plt.xticks(rotation = 360)

# adding the legend

plt.legend(title = "Attrition", loc = "upper right", fontsize = 6)

# adding the data labels 

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")

#showing the chart

plt.show()

# %% [markdown]
# Employees who have worked in 3 companies or fewer account for the highest number of attrition cases, with a total of 153 employees leaving. Remarkably, this group also comprises the largest number of employees within the organization, totaling 1023 employees. This finding highlights the significance of understanding the attrition drivers for this particular group and implementing measures to mitigate attrition effectively.

# %% [markdown]
# ### Attrition by Distance from Home

# %%
# Segmenting the Distance from Home

bins = [0,11,20,30]
labels = ["0 - 10 km","11 - 19 km", "21 - 30 km"]
df["Distance"] = pd.cut(df["DistanceFromHome"], bins = bins,labels = labels)

# %%
# Employee distribution by Distance from Home

df.groupby(["Distance"]).size().reset_index(name = "count")
# Out:
#      Distance  count
# 0   0 - 10 km   1055
# 1  11 - 19 km    211
# 2  21 - 30 km    204

# %%
# Calculating the attrition by distance from home

Attrition_distance = df.groupby(["Distance", "Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_distance.plot(kind = "bar", figsize = (5,4))

# adding the title and labels

plt.title("Attrition by Distance from Home")
plt.xlabel("Distance from Home")
plt.ylabel("count")
plt.xticks(rotation = 45)

# adding the data labels 

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")


# adding the legend

plt.legend(title = "Attrition", loc = "upper right", fontsize = (6))


#showing the chart
plt.show()

# %% [markdown]
# Employees who reside within 10 km of their workplace are the most affected by attrition, with a total of 148 employees leaving the company. It's interesting to note that this group also constitutes the largest portion of the workforce, with a total of 1055 employees. This finding suggests the need for a closer examination of attrition factors affecting employees living in close proximity to the workplace. Understanding and addressing these factors may contribute to better employee retention strategies.

# %% [markdown]
# ### Attrition by Overtime

# %%
# Employee distribution by Overtime

df.groupby(["OverTime"]).size().reset_index(name="count")
# Out:
#   OverTime  count
# 0       No   1054
# 1      Yes    416

# %%
# Calculating the attrition by Overtime

Attrition_overtime = df.groupby(["OverTime","Attrition"]).size().unstack().fillna(0)

# Plotting the chart

ax = Attrition_overtime.plot(kind = "bar", figsize=(5,4))

# Title and labels

plt.title("Attrition by OverTime")
plt.xlabel("OverTime")
plt.ylabel("Count")
plt.xticks(rotation = 360)

# Adding legend

plt.legend(title = "Attrition",loc = "upper right",fontsize = 6)

# Adding labels to the bars

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")
    
# Show the plot

plt.show()

# %% [markdown]
# Employees who worked overtime are the most affected by attrition, with a total of 127 employees leaving the company. Interestingly, this group constitutes the smallest portion of the workforce, with a total of 416 employees. This finding suggests the need to delve deeper into the factors contributing to attrition among employees who put in extra hours. Addressing these factors may help improve retention rates among employees who work overtime.

# %% [markdown]
# ### Attrition by Monthly Salary

# %%
# segmenting the employees by Salary

bins = [1000,7000,13000,20000]
Labels = ["Low Earners","Mid Earners","High Earners"]
df["Salary Group"] = pd.cut(df["MonthlyIncome"],bins = bins, labels = Labels)

# %%
# Employee distribution by Salary Group

df.groupby(["Salary Group"]).size().reset_index(name = "count")
# Out:
#    Salary Group  count
# 0   Low Earners   1035
# 1   Mid Earners    250
# 2  High Earners    185

# %%
# calculating the attrition by salary 

Attrition_salary = df.groupby(["Salary Group","Attrition"]).size().unstack().fillna(0)

# plotting the chart

ax = Attrition_salary.plot(kind = "bar", figsize = (5,4))

# adding the title and labels

plt.title("Attrition by Monthly Salary")
plt.xlabel("Salary Group")
plt.ylabel("count")
plt.xticks(rotation = 45)

# adding the legend

plt.legend(title = "Attrition", loc = "upper right", fontsize = 6)

# Adding labels to the bars

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha="center", va="center", fontsize=6, color="black", xytext=(0, 5),
                textcoords="offset points")

# showing the chart

plt.show()

# %% [markdown]
# Low Earners, employees who earn below 7000 USD, are the most affected by attrition, with a total of 190 employees leaving the company. It's worth noting that this group of employees represents the largest portion of the workforce, with a total of 1035 employees. This insight highlights the importance of addressing attrition among low earners, as it can significantly impact the company's overall retention efforts and stability.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. **Millennials:** The largest age group (929 employees) experienced the highest attrition, with 137 leaving. Tailored retention strategies are needed.
#
# 2. **Rare Travelers:** Unexpectedly, employees who rarely travel had the highest attrition (156 out of 1043). Investigate reasons behind this trend.
#
# 3. **Education Level 3:** Employees with only level 3 education had the highest attrition (99). Explore factors influencing this group's attrition.
#
# 4. **Marital Status:** Single employees had the highest attrition (120). Address attrition among single employees more effectively.
#
# 5. **Gender:** Male employees had the highest attrition (150), representing the largest group (882). Investigate male-specific attrition factors.
#
# 6. **Junior Employees:** Junior staff (0 - 5 years) faced the highest attrition (162). Target retention efforts for this group.
#
# 7. **Previous Companies:** Employees with three or fewer previous companies had the most attrition (153). Identify factors affecting this group.
#
# 8. **Proximity:** Employees living within 10 km of work had the highest attrition (148). Investigate local attrition factors.
#
# 9. **Overtime Workers:** Overtime employees experienced high attrition (127) among the smallest group (416). Address their specific attrition causes.
#
# 10. **Low Earners:** Low earners (190) had the highest attrition among the largest group (1035). Focus on their job satisfaction and retention.

# %% [markdown]
# ## Recommendations

# %% [markdown]
# 1. Develop age-specific retention strategies for Millennials.
#
# 2. Investigate and address attrition causes among rare travelers.
#
# 3. Implement tailored retention measures for level 3 education employees.
#
# 4. Create strategies to retain single employees.
#
# 5. Address male-specific attrition factors.
#
# 6. Focus on retaining junior employees.
#
# 7. Develop retention strategies for employees with minimal previous work experience.
#
# 8. Investigate and address local attrition factors.
#
# 9. Improve job satisfaction and retention for overtime workers.
#
# 10. Enhance job satisfaction and retention efforts for low earners.
